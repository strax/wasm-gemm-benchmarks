# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("results3.csv", index_col = "m", usecols=["m", "gflops_js", "gflops_wasm"])

# %%
data.keys()
# Out:
# Index(['gflops_js', 'gflops_wasm'], dtype='object')

# %%
data
# Out:
#      gflops_js  gflops_wasm
# m
# 16     0.00696      1.95048
# 32     0.74304      8.29570
# 48     0.72830      9.06492
# 64     0.73204      9.53251
# 80     0.74096      9.84615
# 96     0.75606      9.77069
# 112    0.74786     10.08563
# 128    0.73348      9.76328
# 144    0.73856     10.07077
# 160    0.73565      9.69582
# 176    0.73751      9.65429
# 192    0.62834      9.19147
# 208    0.72786      9.07743
# 224    0.69188      8.62912
# 240    0.70321      8.52649
# 256    0.50386      5.72269
# 272    0.72841      8.65198
# 288    0.71448      8.41908
# 304    0.71735      8.36294
# 320    0.59955      7.72830
# 336    0.70607      8.47089
# 352    0.67063      8.37318
# 368    0.71053      8.33588
# 384    0.52384      6.12582
# 400    0.71796      8.32439
# 416    0.67363      8.10736
# 432    0.70334      8.18622
# 448    0.57534      6.92875
# 464    0.70775      7.99316
# 480    0.64045      7.42619
# 496    0.69212      8.09800
# 512    0.47211      5.45935
# ...

# %%
data.plot()

# %%
pd.read_csv("results4.csv", index_col = "m", usecols=["m", "gflops_js", "gflops_wasm"]).plot()
